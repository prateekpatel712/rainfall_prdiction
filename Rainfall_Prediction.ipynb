# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\prate\OneDrive\Desktop\austin_weather.csv")
dataset.head(10)
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
# 5  2013-12-26         57        48        39            39           36
# 6  2013-12-27         60        53        45            41           39
# 7  2013-12-28         62        51        40            43           39
# 8  2013-12-29         64        50        36            49           41
# 9  2013-12-30         44        40        35            31           26
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# ...

# %%
data = dataset.drop(["Date", "Events"], axis =1, inplace=True)

# %%
dataset
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
data = dataset.replace("T", 0.0, inplace = True)
data

# %%
data = dataset.replace("-", 0.0, inplace = True)
dataset
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
dataset.to_csv("austin_weather_final.csv")

# %%
#Importing libraries 
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("austin_weather_final.csv")

# %%
data.head(7)
# Out:
#    Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0           0         74        60        45           67.0          49.0
# 1           1         56        48        39           43.0          36.0
# 2           2         58        45        32           31.0          27.0
# 3           3         61        46        31           36.0          28.0
# 4           4         58        50        41           44.0          40.0
# 5           5         57        48        39           39.0          36.0
# 6           6         60        53        45           41.0          39.0
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0          43.0                 93.0                75.0                57.0
# 1          28.0                 93.0                68.0                43.0
# 2          23.0                 76.0                52.0                27.0
# ...

# %%
data.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
data
# Out:
#       TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0            74        60        45           67.0          49.0
# 1            56        48        39           43.0          36.0
# 2            58        45        32           31.0          27.0
# 3            61        46        31           36.0          28.0
# 4            58        50        41           44.0          40.0
# ...         ...       ...       ...            ...           ...
# 1314        103        89        75           71.0          67.0
# 1315        105        91        76           71.0          64.0
# 1316        107        92        77           72.0          64.0
# 1317        106        93        79           70.0          68.0
# 1318         99        88        77           66.0          61.0
#
#       DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# 0             43.0                 93.0                75.0
# 1             28.0                 93.0                68.0
# ...

# %%
x = data.iloc[:,:-1]
y = data["PrecipitationSumInches"]

# %%
#Training the dataset 
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=41)

# %%
#Linear Model Classifier 
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# *Plotting the Graph*

# %%
#Reshaping y to 2d vector to plot a graph
# y = y.values.reshape(-1,1)
x.shape
# Out:
# (1319, 18)

# %%
#Plotting the graph
day_index = 257
day = [i for i in range(y.size)]

# %%
plt.title("PREDICTION TREND GRAPH")
plt.scatter(day, y, c='g')
plt.scatter(day[day_index], y[day_index], c='r')
plt.xlabel("Days")
plt.ylabel("Prediction in inches")    
plt.legend()
plt.show;
# Out:
# C:\Users\prate\AppData\Local\Temp\ipykernel_17860\2903558409.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x_vis = x.filter(["TempAvgF", "DewPointAvgF", "HumidityAvgPercent", "SeaLevelPressureAvgInches", "VisibilityAvgMiles", "WindAvgMPH"]);

# %%
print("Prediction vs attribute trend graph")
for i in range(x_vis.columns.size):
    plt.subplot(4,2, i+1)
    plt.scatter(day, x_vis[x_vis.columns.values[i][:100]], c='g')
    plt.scatter(day[day_index], x_vis[x_vis.columns.values[i]][day_index], c='r')
    plt.title(x_vis.columns.values[i])
plt.show();
# Out:
# Prediction vs attribute trend graph

# %%
#It seems that the rainfall can happen when their is high temperature and humidity
